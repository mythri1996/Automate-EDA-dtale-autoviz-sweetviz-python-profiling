# %% [markdown]
# # dtale

# %%
import dtale

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\pc\Desktop\class\train.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://HP:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #    pandas profiling

# %%
import pandas_profiling

# %%
import seaborn as sns

# %%
df1=sns.load_dataset("tips")

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df1, explorative=True)
profile.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/20 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # sweetviz

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.0-py3-none-any.whl (15.1 MB)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from sweetviz) (3.4.1)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-5.1.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from sweetviz) (1.20.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from sweetviz) (1.6.2)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from sweetviz) (1.2.4)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from sweetviz) (4.60.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jinja2>=2.11.1->sweetviz) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.1)
# Requirement already satisfied: six in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from cycler>=0.10->matplotlib>=3.1.3->sweetviz) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.1)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.1.2 sweetviz-2.1.0

# %%
import sweetviz as sv
df2=sns.load_dataset("titanic")
report=sv.analyze(df2)
report.show_html("eda_titanic.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report eda_titanic.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Autoviz

# %%
# !pip install autoviz
# Out:
# Collecting autoviz
#   Using cached autoviz-0.0.81-py3-none-any.whl (35 kB)
# Requirement already satisfied: ipython in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from autoviz) (7.22.0)
# Requirement already satisfied: seaborn in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from autoviz) (0.11.1)
# Requirement already satisfied: pandas in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from autoviz) (1.2.4)
# Requirement already satisfied: matplotlib in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from autoviz) (3.4.1)
# Requirement already satisfied: scikit-learn in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from autoviz) (0.24.1)
# Collecting xgboost
#   Using cached xgboost-1.4.1-py3-none-win_amd64.whl (97.8 MB)
# Requirement already satisfied: statsmodels in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from autoviz) (0.12.2)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: setuptools>=18.5 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (52.0.0.post20210125)
# Requirement already satisfied: colorama in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: decorator in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (5.0.5)
# Requirement already satisfied: backcall in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (3.0.17)
# Requirement already satisfied: pygments in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipython->autoviz) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jedi>=0.16->ipython->autoviz) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from traitlets>=4.2->ipython->autoviz) (0.2.0)
# Requirement already satisfied: ipykernel in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jupyter->autoviz) (5.3.4)
# Requirement already satisfied: ipywidgets in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jupyter->autoviz) (7.6.3)
# Requirement already satisfied: jupyter-console in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jupyter->autoviz) (6.4.0)
# Requirement already satisfied: qtconsole in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jupyter->autoviz) (5.0.3)
# Requirement already satisfied: nbconvert in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jupyter->autoviz) (6.0.7)
# Requirement already satisfied: notebook in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jupyter->autoviz) (6.3.0)
# Requirement already satisfied: jupyter-client in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipykernel->jupyter->autoviz) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipykernel->jupyter->autoviz) (6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipywidgets->jupyter->autoviz) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipywidgets->jupyter->autoviz) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from ipywidgets->jupyter->autoviz) (5.1.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (4.7.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (1.15.0)
# Requirement already satisfied: argon2-cffi in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from notebook->jupyter->autoviz) (20.1.0)
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
# Requirement already satisfied: terminado>=0.8.3 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from notebook->jupyter->autoviz) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from notebook->jupyter->autoviz) (0.10.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from notebook->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: jinja2 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from notebook->jupyter->autoviz) (2.11.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from notebook->jupyter->autoviz) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jupyter-client->ipykernel->jupyter->autoviz) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (228)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->autoviz) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from argon2-cffi->notebook->jupyter->autoviz) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->autoviz) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from jinja2->notebook->jupyter->autoviz) (1.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib->autoviz) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib->autoviz) (1.20.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib->autoviz) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib->autoviz) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from matplotlib->autoviz) (1.3.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbconvert->jupyter->autoviz) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbconvert->jupyter->autoviz) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbconvert->jupyter->autoviz) (1.4.3)
# Requirement already satisfied: testpath in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbconvert->jupyter->autoviz) (0.4.4)
# Requirement already satisfied: defusedxml in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbconvert->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: bleach in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbconvert->jupyter->autoviz) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbconvert->jupyter->autoviz) (0.8.4)
# Requirement already satisfied: nest-asyncio in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviz) (1.10)
# Requirement already satisfied: webencodings in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from bleach->nbconvert->jupyter->autoviz) (0.5.1)
# Requirement already satisfied: packaging in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from bleach->nbconvert->jupyter->autoviz) (20.9)
# Requirement already satisfied: pytz>=2017.3 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from pandas->autoviz) (2021.1)
# Requirement already satisfied: qtpy in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from qtconsole->jupyter->autoviz) (1.9.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from scikit-learn->autoviz) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from scikit-learn->autoviz) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from scikit-learn->autoviz) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\pc\anaconda3\envs\edafile\lib\site-packages (from statsmodels->autoviz) (0.5.1)
# Installing collected packages: xgboost, jupyter, autoviz

# %%
import autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %%
df = AV.AutoViz(r"C:\Users\pc\Desktop\class\train.csv")
# Out:
# Shape of your Data Set: (2000, 21)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  13
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  6
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     21 Predictors classified...
#         This does not include the Target column(s)
#         No variables removed since no ID or low-information variables found in data set
# Number of All Scatter Plots = 3
# Time to run AutoViz (in seconds) = 40.987
#
#  ###################### VISUALIZATION Completed ########################
